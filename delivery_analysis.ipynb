# %%
import pandas as pd

# %%
total_earnings = df['earnings'].sum()
total_fuel = df['fuel'].sum()
total_profit = df['profit'].sum()

print("Total Earnings: ₹", total_earnings)
print("Total Fuel Cost: ₹", total_fuel)
print("Total Profit: ₹", total_profit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 total_earnings = df['earnings'].sum()
#       2 total_fuel = df['fuel'].sum()
#       3 total_profit = df['profit'].sum()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Load your data
df = pd.read_csv("C:\Users\admin\Documents\delivery performance analysis\real data.xlsx")

# Preview
print(df.head())

# Check for nulls
print(df.isnull().sum())

# Convert 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])
# Out:
#   Cell In[3], line 4
#     df = pd.read_csv("C:\Users\admin\Documents\delivery performance analysis\real data.xlsx")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
print("Total Earning: ₹", df['Earning (₹)'].sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("Total Earning: ₹", df['Earning (₹)'].sum())
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Load your data
df = pd.read_excel("C:\\Users\\admin\\Documents\\delivery performance analysis\\real data.xlsx")

# Preview
print(df.head())
# Out:
#          date  order_id distance_km take_times  earnings  fuel  \
# 0  23\07\2025      7684       5.2KM      40MIN      30.0    11
# 1  23\07\2025      4082         3.9      23MIN      24.0     8
# 2  23\07\2025      3906         8.5      40MIN      45.0    18
# 3  23\07\2025      3085       4.8KM      17MIN      54.0    10
# 4  23\07\2025      1235       2.5KM      10MIN      20.0     4
#
#    customer_rating          zone  profit
# 0              4.5  METTUPALAYAM    19.0
# 1              5.0  METTUPALAYAM    16.0
# 2              4.4     KARAMADAI    27.0
# 3              5.0  METTUPALAYAM    44.0
# 4              4.4  METTUPALAYAM    16.0

# %%
total_earnings = df['earnings'].sum()
total_fuel = df['fuel'].sum()
total_profit = df['profit'].sum()

print("Total Earnings: ₹", total_earnings)
print("Total Fuel Cost: ₹", total_fuel)
print("Total Profit: ₹", total_profit)
# Out:
# Total Earnings: ₹ 950.25
# Total Fuel Cost: ₹ 252
# Total Profit: ₹ 698.25
